# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035    
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard

# %%
pd.set_option('display.max_columns', None)

# %%
comments.head(50)
# Out:
#         id                              name  anonymous hostProgramName  \
# 0   300758                         Anonymous       True            None
# 1   300701                  Omezzine Meysour      False            None
# 2   300599                         Anonymous       True            None
# 3   300597                          Pim Blom      False            None
# 4   300526                   Nancy Omozokpea      False            None
# 5   300130             Michiel van der merwe      False            None
# 6   300057                         Anonymous       True            None
# 7   299681                Buse Dilara Kilinc      False            None
# 8   299425       Jose Daniel De Luis Ramirez      False            None
# 9   299312                         Anonymous       True            None
# 10  299301                  julika brockhaus      False            None
# 11  299046                         Anonymous       True            None
# ...

# %%
comments['hostProgramName'].isnull().sum()
# Out:
# 2072

# %%
comments['hostProgramName'].shape
# Out:
# (3923,)

# %%
comments['school'].value_counts()
# Out:
# springboard    1476
# ironhack       1255
# app-academy    1192
# Name: school, dtype: int64

# %%
comments['program'].value_counts()
# Out:
# Software Engineer Track: In-Person                       794
# Full-time Web Development Bootcamp                       362
# Data Science Career Track                                300
# UI/UX Design Career Track                                283
# Web Development Bootcamp                                 203
# Data Analytics Career Track                              195
# Full-time UX/UI Design Bootcamp                          165
#                                                          159
# Software Engineer Track: Online                          157
# UX Career Track                                          145
# UX Design                                                133
# UX/UI Design Bootcamp                                    103
# Part-time Web Development                                 99
# Software Engineering Career Track                         94
# Bootcamp Prep                                             80
# ...

# %%
display(comments.columns)
# Out:
# Index(['id', 'name', 'anonymous', 'hostProgramName', 'graduatingYear',
#        'isAlumni', 'jobTitle', 'tagline', 'body', 'rawBody', 'createdAt',
#        'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall',
#        'curriculum', 'jobSupport', 'review_body', 'school'],
#       dtype='object')

# %%
schools_df = comments[['id',  'graduatingYear',
       'isAlumni', 'tagline', 'rawBody', 'createdAt',
       'program', 'overallScore', 'overall',
       'curriculum', 'jobSupport', 'school']]

# %%
schools_df
# Out:
#           id  graduatingYear  isAlumni  \
# 0     300758          2023.0     False
# 1     300701          2023.0     False
# 2     300599          2023.0     False
# 3     300597          2023.0     False
# 4     300526          2023.0     False
# ...      ...             ...       ...
# 1471  234894          2015.0      True
# 1472  234877          2015.0      True
# 1473  234838          2016.0      True
# 1474  242681          2016.0      True
# 1475  234178          2016.0      True
#
#                                                 tagline  \
# 0     intensiv &amp; stressful, support of teaching ...
# 1                                   Amazing experience!
# 2          Great bootcamp if you want to change career!
# 3                         Great way to become a web dev
# 4      It was well structured and very encouraging Team
# ...                                                 ...
# 1471              Excellent and comprehensive UX course
# ...

# %%
print(comments['overall'].dtype)
# Out:
# object

# %%
comments['overall'] = comments['overall'].astype(float)

# %%
comments['overall'].mean()
# Out:
# 4.725019166879632

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])
    
    price_min = {'priceMin': data['content']['priceMin']}
    price_min_df = json_normalize(price_min)

    price_max = {'priceMax': data['content']['priceMax']}
    price_max_df = json_normalize(price_max)

    
    price_df = pd.concat([price_min_df, price_max_df], axis=1, keys=['priceMin', 'priceMax'])
    
    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    price_df['school'] = school

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id
    price_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df, price_df


locations_list = []
courses_list = []
badges_list = []
schools_list = []
price_df_list = []


for school, id in schools.items():
    print(school)
    a,b,c,d,e = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
    price_df_list.append(e)
# Out:
# ironhack
# C:\Users\miquelemelo\AppData\Local\Temp\ipykernel_2096\3187811556.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   price_min_df = json_normalize(price_min)
# C:\Users\miquelemelo\AppData\Local\Temp\ipykernel_2096\3187811556.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   price_max_df = json_normalize(price_max)
# C:\Users\miquelemelo\AppData\Local\Temp\ipykernel_2096\3187811556.py:23: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# app-academy
# C:\Users\miquelemelo\AppData\Local\Temp\ipykernel_2096\3187811556.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   price_min_df = json_normalize(price_min)
# ...

# %%
schools_list
# Out:
# [               website                                        description  \
#  0  www.ironhack.com/en  <span class="truncatable"><p>Ironhack is a glo...
#
#                                               LogoUrl    school  school_id
#  0  https://d92mrp7hetgfk.cloudfront.net/images/si...  ironhack      10828  ,
#           website                                        description  \
#  0  appacademy.io  <span class="truncatable"><p>Founded in 2012, ...
#
#                                               LogoUrl       school  school_id
#  0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525  ,
#                                               website  \
#  0  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                           description  \
#  0  <span class="truncatable"><p>Springboard is an...
#
#                                               LogoUrl       school  school_id
# ...

# %%
schools = pd.concat(schools_list)

# %%
locations = pd.concat(locations_list)

# %%
locations
# Out:
#       id                       description  country.id   country.name  \
# 0  15901                   Berlin, Germany        57.0        Germany
# 1  16022               Mexico City, Mexico        29.0         Mexico
# 2  16086            Amsterdam, Netherlands        59.0    Netherlands
# 3  16088                 Sao Paulo, Brazil        42.0         Brazil
# 4  16109                     Paris, France        38.0         France
# 5  16375          Miami, FL, United States         1.0  United States
# 6  16376                     Madrid, Spain        12.0          Spain
# 7  16377                  Barcelona, Spain        12.0          Spain
# 8  16709                  Lisbon, Portugal        28.0       Portugal
# 9  17233                            Online         NaN            NaN
# 0  15704  San Francisco, CA, United States         1.0  United States
# 1  15705  New York City, NY, United States         1.0  United States
# ...

# %%
courses = pd.concat(courses_list)
badges= pd.concat(badges_list)
price = pd.concat(price_df_list)

# %%
#importing packages
import mysql.connector 
import pandas as pd
import numpy as np
import getpass
from sqlalchemy import create_engine
# !pip install pymysql

# %%
#saved_password = getpass.getpass()
# Out:
# ········

# %%
#cnx = mysql.connector.connect(user = 'root', password = saved_password, host ='localhost', database = 'new_schema', auth_plugin='mysql_native_password')

# %%
#cnx.is_connected()
# Out:
# True

# %%
# create sqlalchemy engine
user = "root"
pw=saved_password
engine = create_engine("mysql+pymysql://root:miqueleluce@localhost/new_schema")

# %%
# Insert whole DataFrame into MySQL
courses.to_sql('courses', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 27

# %%
price.to_sql('price', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 3

# %%
badges.to_sql('badges', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 9

# %%
locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 14

# %%
schools.to_sql('schools', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 3

# %%
schools_df.to_sql('schools_df', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 3923

# %%
cursor = cnx.cursor()
